# %%
import pandas as pd

df = pd.read_csv("/Users/ethannordman/Desktop/UCS-Satellite-Database 5-1-2023.csv")

# %%
df.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 0  1HOPSAT-TD (1st-generation High Optical Perfor...
# 1                            AAC AIS-Sat1 (Kelpie 1)
# 2                                           Aalto-1
# 3                                              AAt-4
# 4                           ABS-2 (Koreasat-8, ST-3)
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 0                         1HOPSAT-TD                         NR
# 1            AAC AIS-Sat1 (Kelpie 1)             United Kingdom
# 2                            Aalto-1                    Finland
# 3                              AAt-4                    Denmark
# 4                              ABS-2                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 0                       USA                   Hera Systems  Commercial
# 1            United Kingdom                AAC Clyde Space  Commercial
# ...

# %%
# Check the attributes in Class of Orbit
df['Class of Orbit'].unique()
# Out:
# array(['LEO', 'GEO', 'Elliptical', 'MEO', 'LEo', nan], dtype=object)

# %%
# See the filtered data
geo_df = df[df['Class of Orbit'] == 'GEO'] # Select, From, Where
geo_df.head()
# Out:
#                   Name of Satellite, Alternate Names  \
# 4                           ABS-2 (Koreasat-8, ST-3)
# 5                                             ABS-2A
# 6                                            ABS-3A
# 7  ABS-4 (ABS-2i, MBSat, Mobile Broadcasting Sate...
# 8  ABS-6 (ABS-1, LMI-1, Lockheed Martin-Intersput...
#
#   Current Official Name of Satellite Country/Org of UN Registry  \
# 4                              ABS-2                         NR
# 5                             ABS-2A                         NR
# 6                             ABS-3A                         NR
# 7                              ABS-4                         NR
# 8                              ABS-6                         NR
#
#   Country of Operator/Owner                 Operator/Owner       Users  \
# 4             Multinational  Asia Broadcast Satellite Ltd.  Commercial
# 5             Multinational  Asia Broadcast Satellite Ltd.  Commercial
# ...
